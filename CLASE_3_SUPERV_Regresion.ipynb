# %% [markdown]
# <a href="https://colab.research.google.com/github/marioguerrerosalah/APRENDIZAJE--SUPERVISADO/blob/main/CLASE_3_SUPERV_Regresion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Regresión lineal

# %%
import pandas as pd

from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/APREN. SUPERVISADO/Dataset_heating_cost.csv', encoding="latin1")
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#    Casa  Costo de calefacción (USD)  Temp externa media (ºF)  \
# 0     1                         250                       35
# 1     2                         360                       29
# 2     3                         165                       36
# 3     4                          43                       60
# 4     5                          92                       65
#
#    Aislamiento del atico (pulgadas)  Antiguedad del calentador (años)  Garaje
# 0                                 3                                 6       0
# 1                                 4                                10       1
# 2                                 7                                 3       0
# 3                                 6                                 9       0
# 4                                 5                                 6       0

# %% [markdown]
# ## Modelo de regresión lineal simple
#
# $$\hat{Y}=a+bX$$
#
# Donde:
#
# **$\hat{Y}$**: predicción de Y
# **Y**: variable dependiente (que queremos predecir)
# **X**: variable(s) independiente(s) (predictores)
# **a**: intercepto (valor de Y cuando X = 0)
# **b**: pendiente (cuánto cambia Y por cada unidad de X)

# %%
Y = df['Costo de calefacción (USD)']
X = df['Temp externa media (ºF)']

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 1)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [388.80195166]
# Pendiente (b): [[-4.93419225]]

# %%
modelo.predict([[35]])
# Out:
# array([[216.10522295]])

# %% [markdown]
# **¿Cómo funciona la regresión?**

# %% [markdown]
# La idea es minimizar la suma de los errores al cuadrado, es decir:
# $$Error=Y− \hat{Y}$$
#
# Queremos minimizar:
#
# $$Min ∑(Yi−\hat{Y})^2$$

# %% [markdown]
# Ahora veremos como calcular la ecuación de la regresión
#
# $$\hat{Y}=a+bX$$
#
# El coeficiente de la variable independiente se calcula de la siguiente manera:
#
# $$b=\frac{∑(Xi​−\bar{X})(Yi​−\bar{Y})}{∑(Xi​−\bar{X})^2}$$​

# %%
b= sum((X-X.mean())*(Y-Y.mean()))/sum((X-X.mean())**2)
b
# Out:
# array([-4.93419225])

# %% [markdown]
# El intercepto se calcula de la siguiente manera
#
# $$a=\bar{Y}−b\bar{X}$$

# %%
a= Y.mean()-b*X.mean()
a
# Out:
# array([388.80195166])

# %% [markdown]
# Por lo tanto, la ecuación de la regresión sería:
#
# $$\hat{Y}=388.8 + -4.93 * X$$

# %% [markdown]
# Teniendo en cuenta que Y es el costo de la calefacción y X es la temperatura exterior en ºF. Si se tiene para la casa 1, una temperatura de 35 ºF, el costo de calefacción predicho es de:
#
# $$\hat{Y}=388.8 + -4.93 * 35$$
# $$\hat{Y}=216.10$$
#
# Teniendo en cuenta que el valor real fue de 250 dolares, se tuvo un error de
#
# $$Error=Y− \hat{Y}$$
# $$Error=250− 216.10= 33.90$$
#
# Lo que busca la regresión es minimizar la sumatoria de los errores de todas las observaciones

# %%
import statsmodels.api as sm

# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión
modelo_sm = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo (incluye la ecuación y ANOVA)
print(modelo_sm.summary())

# Obtener y mostrar los residuales
residuales = modelo_sm.resid
print("\nResiduales:")
print(residuales)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.659
# Model:                            OLS   Adj. R-squared:                  0.640
# Method:                 Least Squares   F-statistic:                     34.72
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           1.41e-05
# Time:                        15:02:52   Log-Likelihood:                -110.36
# No. Observations:                  20   AIC:                             224.7
# Df Residuals:                      18   BIC:                             226.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        388.8020     34.241     11.355      0.000     316.865     460.739
# x1            -4.9342      0.837     -5.892      0.000      -6.694      -3.175
# ==============================================================================
# Omnibus:                        2.208   Durbin-Watson:                   1.367
# Prob(Omnibus):                  0.332   Jarque-Bera (JB):                1.630
# Skew:                           0.683   Prob(JB):                        0.443
# Kurtosis:                       2.698   Cond. No.                         98.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Residuales:
# [  33.89477705  114.28962356  -46.1710307   -49.75041672   23.92054452
#   -40.77618419   15.53997083  -64.26260592  -55.18391443    2.57862203
#   -49.35557022   53.03927629  109.88189332  123.63154605  -20.75041672
#   -18.11810668   -8.61880122   -1.4342617   -20.57876094 -101.77618419]

# %% [markdown]
# **Interpretación de los Resultados de la Regresión OLS**
#
#  **R-squared (R²)**: Este valor (0.659) indica que aproximadamente el 65.9% de la variabilidad en el costo de la calefacción puede ser explicada por la temperatura externa media. Un valor más alto significa un mejor ajuste del modelo.
#
#  **Adj. R-squared (R² ajustado)**: Similar al R-squared, pero ajustado por el número de predictores en el modelo. Es útil para comparar modelos con diferente número de variables.
#
#  **F-statistic**: Esta es una prueba de la significancia general del modelo. Un valor alto (34.72) con una probabilidad baja (Prob (F-statistic) de 1.41e-05) sugiere que el modelo es estadísticamente significativo.
#
#  **coef (Coeficientes):**
#      const (Intercepto): El valor de 388.8020 es el costo de calefacción predicho cuando la temperatura externa es 0°F.
#      x1 (Pendiente): El valor de -4.9342 indica que por cada grado Fahrenheit que aumenta la temperatura externa, el costo de la calefacción disminuye en aproximadamente 4.93 USD.
#
#  **P>|t| (Valor p):** Estos valores prueban la significancia de cada coeficiente. Un valor p bajo (generalmente < 0.05) indica que el coeficiente es estadísticamente significativo. En tu caso, tanto el intercepto como el coeficiente de la temperatura son significativos.
#
#  **[0.025 0.975] (Intervalo de Confianza)**: Este es el rango en el que se espera que se encuentre el verdadero valor del coeficiente con un 95% de confianza.

# %% [markdown]
# **Grafico de los residuales**

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats

# Gráfico de residuales vs. valores ajustados
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.scatter(modelo_sm.fittedvalues, residuales)
plt.axhline(y=0, color='r', linestyle='--')
plt.xlabel('Valores Ajustados')
plt.ylabel('Residuales')
plt.title('Gráfico de Residuales vs. Valores Ajustados')

# Gráfico Q-Q de los residuales
plt.subplot(1, 2, 2)
stats.probplot(residuales, dist="norm", plot=plt)
plt.title('Gráfico Q-Q de los Residuales')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Metricas de desempeño

# %%
y_real= df['Costo de calefacción (USD)']
y_pred= modelo.predict(X)

# %%
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
import numpy as np

# y_real: valores verdaderos
# y_pred: valores predichos por el modelo

r2 = r2_score(y_real, y_pred)
mse = mean_squared_error(y_real, y_pred)
rmse = np.sqrt(mse)  # raíz del MSE
mae = mean_absolute_error(y_real, y_pred)

print("R^2:", r2)
print("RMSE:", rmse)
print("MAE:", mae)
# Out:
# R^2: 0.6585465900839088
# RMSE: 60.29129657850376
# MAE: 47.677625364633975

# %% [markdown]
# # Ejercicio práctico
# Ahora queremos mejorar el modelo, por lo tanto, vamos a probar con las otras variables independientes disponibles en el dataset, hasta obtener el mejor modelo.
# Podemos hacer varios modelos de regresion lineal simple y múltiple para comparar.

# %% [markdown]
# # Problemas que se pueden presentar en la regresión lineal multivariante
#
# # Multicolinealidad
# - Es cuando dos o más variables independientes están fuertemente correlacionadas entre sí.
#
# ## Cómo detectarla:
# - Calculando el VIF (Variance Inflation Factor): valores > 5 o 10 indican problemas.
#
# ## Soluciones:
# - Eliminar variables redundantes, combinar variables, usar regresión ridge o LASSO.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Definir las variables independientes
X_vif = df[['Temp externa media (ºF)', 'Aislamiento del atico (pulgadas)', 'Antiguedad del calentador (años)', 'Garaje']]

# Calcular el VIF para cada variable
vif_data = pd.DataFrame()
vif_data["feature"] = X_vif.columns
vif_data["VIF"] = [variance_inflation_factor(X_vif.values, i) for i in range(len(X_vif.columns))]

print(vif_data)
# Out:
#                             feature       VIF
# 0           Temp externa media (ºF)  3.434863
# 1  Aislamiento del atico (pulgadas)  5.685857
# 2  Antiguedad del calentador (años)  5.568800
# 3                            Garaje  2.114005

# %% [markdown]
# # Heterocedasticidad
#
# - Es cuando la varianza de los errores no es constante a lo largo de los valores de X.
# - Los errores estándar no son confiables → los tests estadísticos (como el p-valor) pueden ser incorrectos.
#
# ## Cómo detectarlo:
# - Gráfico de residuos vs. predicciones: si hay forma de "cono", hay heterocedasticidad.
# - Test de Breusch-Pagan.
#
# ##Soluciones:
# - Transformar variables (log, sqrt), usar regresión robusta.

# %% [markdown]
# #Ejercicio con aislamiento del atico

# %%
##Ejercicio con aislamiento del atico

Y = df['Costo de calefacción (USD)']
X = df['Aislamiento del atico (pulgadas)']

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 1)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [275.02917203]
# Pendiente (b): [[-10.98884599]]

# %%
# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión
modelo_sm = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo (incluye la ecuación y ANOVA)
print(modelo_sm.summary())

# Obtener y mostrar los residuales
residuales = modelo_sm.resid
print("\nResiduales:")
print(residuales)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.274
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):              0.274
# Time:                        15:34:10   Log-Likelihood:                -120.42
# No. Observations:                  20   AIC:                             244.8
# Df Residuals:                      18   BIC:                             246.8
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        275.0292     66.137      4.158      0.001     136.080     413.979
# x1           -10.9888      9.736     -1.129      0.274     -31.443       9.465
# ==============================================================================
# Omnibus:                        1.861   Durbin-Watson:                   1.586
# Prob(Omnibus):                  0.394   Jarque-Bera (JB):                1.013
# Skew:                           0.097   Prob(JB):                        0.603
# Kurtosis:                       1.915   Cond. No.                         19.5
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Residuales:
# [   7.93736594  128.92621193  -33.10725011 -166.0960961  -128.08494208
#   -20.08494208  145.9039039   124.85928786   53.87044187 -133.05148005
#   -70.16302016  -15.08494208  179.91505792   88.92621193 -115.11840412
#    51.91505792 -104.10725011    2.88159588   58.87044187  -59.10725011]

# %% [markdown]
# ##Ejercicio con Antiguedad del calentador (años)

# %%
Y = df['Costo de calefacción (USD)']
X = df['Antiguedad del calentador (años)']

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 1)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [86.18396226]
# Pendiente (b): [[17.00943396]]

# %%
# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión
modelo_sm = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo (incluye la ecuación y ANOVA)
print(modelo_sm.summary())

# Obtener y mostrar los residuales
residuales = modelo_sm.resid
print("\nResiduales:")
print(residuales)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.288
# Model:                            OLS   Adj. R-squared:                  0.249
# Method:                 Least Squares   F-statistic:                     7.284
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):             0.0147
# Time:                        15:37:22   Log-Likelihood:                -117.71
# No. Observations:                  20   AIC:                             239.4
# Df Residuals:                      18   BIC:                             241.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         86.1840     48.656      1.771      0.093     -16.039     188.407
# x1            17.0094      6.303      2.699      0.015       3.768      30.251
# ==============================================================================
# Omnibus:                        0.453   Durbin-Watson:                   1.710
# Prob(Omnibus):                  0.797   Jarque-Bera (JB):                0.543
# Skew:                          -0.286   Prob(JB):                        0.762
# Kurtosis:                       2.432   Cond. No.                         18.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Residuales:
# [  61.75943396  103.72169811   27.78773585 -196.26886792  -96.24056604
#    28.76886792  149.75         33.72169811  -43.28773585  -51.23113208
#   -81.22169811  101.80660377   58.6745283   114.75       -116.24056604
#    49.74056604  -43.21226415  -83.28773585   12.74056604  -32.23113208]

# %% [markdown]
# ##Ejercicio con Garaje

# %%
Y = df['Costo de calefacción (USD)']
X = df['Garaje']

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 1)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [142.75]
# Pendiente (b): [[156.25]]

# %%
# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión
modelo_sm = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo (incluye la ecuación y ANOVA)
print(modelo_sm.summary())

# Obtener y mostrar los residuales
residuales = modelo_sm.resid
print("\nResiduales:")
print(residuales)
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      y   R-squared:                       0.550
# Model:                            OLS   Adj. R-squared:                  0.525
# Method:                 Least Squares   F-statistic:                     22.04
# Date:                Thu, 05 Feb 2026   Prob (F-statistic):           0.000181
# Time:                        15:38:42   Log-Likelihood:                -113.11
# No. Observations:                  20   AIC:                             230.2
# Df Residuals:                      18   BIC:                             232.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        142.7500     21.052      6.781      0.000      98.521     186.979
# x1           156.2500     33.286      4.694      0.000      86.318     226.182
# ==============================================================================
# Omnibus:                        4.015   Durbin-Watson:                   1.771
# Prob(Omnibus):                  0.134   Jarque-Bera (JB):                1.400
# Skew:                           0.035   Prob(JB):                        0.497
# Kurtosis:                       1.706   Cond. No.                         2.45
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# Residuales:
# [ 107.25   61.     22.25  -99.75  -50.75   57.25   56.     -9.     87.25
#   -22.75  -69.75  -94.    101.     21.    -70.75  -27.    -48.75 -109.
#    92.25   -3.75]

# %% [markdown]
# # Con dos variables

# %%
Y = df['Costo de calefacción (USD)']
X = df[['Temp externa media (ºF)', 'Garaje']]

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 2)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [300.31861912]
# Pendiente (b): [[-3.56087275 93.48961781]]

# %%
Y = df['Costo de calefacción (USD)']
X = df[['Temp externa media (ºF)', 'Garaje']]

# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión lineal múltiple
modelo_sm_multi = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo
print(modelo_sm_multi.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Costo de calefacción (USD)   R-squared:                       0.805
# Model:                                    OLS   Adj. R-squared:                  0.782
# Method:                         Least Squares   F-statistic:                     34.99
# Date:                        Thu, 05 Feb 2026   Prob (F-statistic):           9.40e-07
# Time:                                15:44:00   Log-Likelihood:                -104.78
# No. Observations:                          20   AIC:                             215.6
# Df Residuals:                              17   BIC:                             218.6
# Df Model:                                   2
# Covariance Type:                    nonrobust
# ===========================================================================================
#                               coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------
# const                     300.3186     36.426      8.245      0.000     223.467     377.170
# Temp externa media (ºF)    -3.5609      0.757     -4.702      0.000      -5.159      -1.963
# Garaje                     93.4896     26.231      3.564      0.002      38.147     148.832
# ==============================================================================
# Omnibus:                        0.944   Durbin-Watson:                   1.604
# Prob(Omnibus):                  0.624   Jarque-Bera (JB):                0.799
# Skew:                           0.201   Prob(JB):                        0.671
# Kurtosis:                       2.107   Cond. No.                         154.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Con todas las variables

# %%
Y = df['Costo de calefacción (USD)']
X = df[['Temp externa media (ºF)', 'Aislamiento del atico (pulgadas)', 'Antiguedad del calentador (años)', 'Garaje']]

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 4)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [361.74611722]
# Pendiente (b): [[ -3.70026343 -11.66339038   3.80222121  71.50165717]]

# %%
Y = df['Costo de calefacción (USD)']
X = df[['Temp externa media (ºF)', 'Aislamiento del atico (pulgadas)', 'Antiguedad del calentador (años)', 'Garaje']]

# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión lineal múltiple con todas las variables
modelo_sm_completo = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo
print(modelo_sm_completo.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Costo de calefacción (USD)   R-squared:                       0.880
# Model:                                    OLS   Adj. R-squared:                  0.848
# Method:                         Least Squares   F-statistic:                     27.57
# Date:                        Thu, 05 Feb 2026   Prob (F-statistic):           9.27e-07
# Time:                                16:00:23   Log-Likelihood:                -99.882
# No. Observations:                          20   AIC:                             209.8
# Df Residuals:                              15   BIC:                             214.7
# Df Model:                                   4
# Covariance Type:                    nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              361.7461     52.590      6.879      0.000     249.654     473.839
# Temp externa media (ºF)             -3.7003      0.686     -5.394      0.000      -5.162      -2.238
# Aislamiento del atico (pulgadas)   -11.6634      3.974     -2.935      0.010     -20.134      -3.193
# Antiguedad del calentador (años)     3.8022      3.324      1.144      0.271      -3.283      10.888
# Garaje                              71.5017     23.155      3.088      0.007      22.149     120.854
# ==============================================================================
# Omnibus:                        2.715   Durbin-Watson:                   2.266
# Prob(Omnibus):                  0.257   Jarque-Bera (JB):                1.370
# Skew:                          -0.289   Prob(JB):                        0.504
# Kurtosis:                       1.856   Cond. No.                         243.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Sacamos antiguedad

# %%
Y = df['Costo de calefacción (USD)']
X = df[['Temp externa media (ºF)', 'Aislamiento del atico (pulgadas)', 'Garaje']]

# Para usar las variables de la regresión, estas deben ser tipo array
X = np.array(X).reshape(-1, 3)
Y = np.array(Y).reshape(-1, 1)

# Modelo de regresión
modelo = LinearRegression()
modelo.fit(X, Y)

# Ver coeficientes
print("Intercepto (a):", modelo.intercept_)
print("Pendiente (b):", modelo.coef_)
# Out:
# Intercepto (a): [393.66568054]
# Pendiente (b): [[ -3.96284721 -11.33395373  77.43210456]]

# %%
Y = df['Costo de calefacción (USD)']
X = df[['Temp externa media (ºF)', 'Aislamiento del atico (pulgadas)',  'Garaje']]

# Intercepto
X_const = sm.add_constant(X)

# Modelo de regresión lineal múltiple con todas las variables
modelo_sm_completo = sm.OLS(Y, X_const).fit()

# Imprimir el resumen del modelo
print(modelo_sm_completo.summary())
# Out:
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Costo de calefacción (USD)   R-squared:                       0.870
# Model:                                    OLS   Adj. R-squared:                  0.845
# Method:                         Least Squares   F-statistic:                     35.64
# Date:                        Thu, 05 Feb 2026   Prob (F-statistic):           2.59e-07
# Time:                                16:10:43   Log-Likelihood:                -100.72
# No. Observations:                          20   AIC:                             209.4
# Df Residuals:                              16   BIC:                             213.4
# Df Model:                                   3
# Covariance Type:                    nonrobust
# ====================================================================================================
#                                        coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------------
# const                              393.6657     45.001      8.748      0.000     298.267     489.064
# Temp externa media (ºF)             -3.9628      0.653     -6.072      0.000      -5.346      -2.579
# Aislamiento del atico (pulgadas)   -11.3340      4.002     -2.832      0.012     -19.817      -2.851
# Garaje                              77.4321     22.783      3.399      0.004      29.135     125.730
# ==============================================================================
# Omnibus:                        2.032   Durbin-Watson:                   2.255
# Prob(Omnibus):                  0.362   Jarque-Bera (JB):                1.035
# Skew:                           0.028   Prob(JB):                        0.596
# Kurtosis:                       1.887   Cond. No.                         212.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
